# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name

    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 618

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "https://api.openweathermap.org/data/2.5/weather?appid=" + weather_api_key + "&units=metric"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = url + "&q=" + city

    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_date = city_weather['dt']

        # Append the City information into city_data list
        city_data.append({"City": city,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

    # pause to avoid rate limiting
    time.sleep(1)

# Indicate that Data Loading is complete
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | palmer
# Processing Record 2 of Set 1 | adampur
# Processing Record 3 of Set 1 | edinburgh of the seven seas
# Processing Record 4 of Set 1 | colonia
# Processing Record 5 of Set 1 | iqaluit
# Processing Record 6 of Set 1 | port mathurin
# Processing Record 7 of Set 1 | waitangi
# Processing Record 8 of Set 1 | miri
# Processing Record 9 of Set 1 | soderhamn
# Processing Record 10 of Set 1 | adamstown
# Processing Record 11 of Set 1 | illizi
# Processing Record 12 of Set 1 | lihue
# Processing Record 13 of Set 1 | 'ohonua
# City not found. Skipping...
# Processing Record 14 of Set 1 | whitehorse
# Processing Record 15 of Set 1 | puerto baquerizo moreno
# Processing Record 16 of Set 1 | cungus
# Processing Record 17 of Set 1 | monduli
# Processing Record 18 of Set 1 | port-aux-francais
# Processing Record 19 of Set 1 | taiohae
# City not found. Skipping...
# Processing Record 20 of Set 1 | alaghsas
# Processing Record 21 of Set 1 | dudinka
# Processing Record 22 of Set 1 | fale old settlement
# Processing Record 23 of Set 1 | invercargill
# Processing Record 24 of Set 1 | alice springs
# Processing Record 25 of Set 1 | lodja
# Processing Record 26 of Set 1 | margaret river
# Processing Record 27 of Set 1 | udachny
# Processing Record 28 of Set 1 | ushuaia
# Processing Record 29 of Set 1 | itapirapua
# Processing Record 30 of Set 1 | ancud
# Processing Record 31 of Set 1 | jaru
# Processing Record 32 of Set 1 | metro
# Processing Record 33 of Set 1 | meulaboh
# Processing Record 34 of Set 1 | yarega
# Processing Record 35 of Set 1 | haiku-pauwela
# Processing Record 36 of Set 1 | qaqortoq
# Processing Record 37 of Set 1 | thompson
# Processing Record 38 of Set 1 | blackmans bay
# Processing Record 39 of Set 1 | badger
# Processing Record 40 of Set 1 | talnakh
# Processing Record 41 of Set 1 | ghat
# Processing Record 42 of Set 1 | bethel
# Processing Record 43 of Set 1 | santa cruz
# Processing Record 44 of Set 1 | west island
# Processing Record 45 of Set 1 | east london
# Processing Record 46 of Set 1 | hengchun
# Processing Record 47 of Set 1 | byumba
# Processing Record 48 of Set 1 | tranovaho
# City not found. Skipping...
# Processing Record 49 of Set 1 | suratgarh
# Processing Record 50 of Set 1 | celestun
# Processing Record 0 of Set 2 | bilibino
# Processing Record 1 of Set 2 | ilulissat
# Processing Record 2 of Set 2 | tiksi
# Processing Record 3 of Set 2 | puerto natales
# Processing Record 4 of Set 2 | pogoanele
# Processing Record 5 of Set 2 | hirara
# Processing Record 6 of Set 2 | albany
# Processing Record 7 of Set 2 | chonchi
# Processing Record 8 of Set 2 | xining
# Processing Record 9 of Set 2 | papatowai
# Processing Record 10 of Set 2 | kingston
# Processing Record 11 of Set 2 | callao
# Processing Record 12 of Set 2 | gizo
# Processing Record 13 of Set 2 | chokwe
# Processing Record 14 of Set 2 | san patricio
# Processing Record 15 of Set 2 | ribeira grande
# Processing Record 16 of Set 2 | sur
# Processing Record 17 of Set 2 | klyuchi
# Processing Record 18 of Set 2 | port elizabeth
# Processing Record 19 of Set 2 | uturoa
# Processing Record 20 of Set 2 | saint-joseph
# Processing Record 21 of Set 2 | sao joao da barra
# Processing Record 22 of Set 2 | kavieng
# Processing Record 23 of Set 2 | burela de cabo
# Processing Record 24 of Set 2 | dubbo
# Processing Record 25 of Set 2 | nyurba
# Processing Record 26 of Set 2 | drayton valley
# Processing Record 27 of Set 2 | tazovsky
# Processing Record 28 of Set 2 | olonkinbyen
# Processing Record 29 of Set 2 | kertih
# Processing Record 30 of Set 2 | howrah
# Processing Record 31 of Set 2 | port saint john's
# Processing Record 32 of Set 2 | jamestown
# Processing Record 33 of Set 2 | citrus springs
# Processing Record 34 of Set 2 | sinabang
# Processing Record 35 of Set 2 | aykhal
# Processing Record 36 of Set 2 | sitka
# Processing Record 37 of Set 2 | saipan
# Processing Record 38 of Set 2 | puerto san carlos
# City not found. Skipping...
# Processing Record 39 of Set 2 | rundu
# Processing Record 40 of Set 2 | inhambane
# Processing Record 41 of Set 2 | smithers
# Processing Record 42 of Set 2 | maumere
# Processing Record 43 of Set 2 | huanggang
# Processing Record 44 of Set 2 | casa santa
# City not found. Skipping...
# Processing Record 45 of Set 2 | grytviken
# Processing Record 46 of Set 2 | fuvahmulah
# City not found. Skipping...
# Processing Record 47 of Set 2 | hsinchu
# Processing Record 48 of Set 2 | alofi
# Processing Record 49 of Set 2 | tura
# Processing Record 0 of Set 3 | gargalianoi
# Processing Record 1 of Set 3 | huocheng
# City not found. Skipping...
# Processing Record 2 of Set 3 | stanley
# Processing Record 3 of Set 3 | lokken
# City not found. Skipping...
# Processing Record 4 of Set 3 | az zubayr
# Processing Record 5 of Set 3 | tobi village
# City not found. Skipping...
# Processing Record 6 of Set 3 | santiago papasquiaro
# Processing Record 7 of Set 3 | hachinohe
# Processing Record 8 of Set 3 | ceeldheer
# Processing Record 9 of Set 3 | galle
# Processing Record 10 of Set 3 | montevideo
# Processing Record 11 of Set 3 | avarua
# Processing Record 12 of Set 3 | puerto ayora
# Processing Record 13 of Set 3 | isafjordur
# Processing Record 14 of Set 3 | kosmach
# Processing Record 15 of Set 3 | bikenibeu village
# Processing Record 16 of Set 3 | nemuro
# Processing Record 17 of Set 3 | inari
# Processing Record 18 of Set 3 | yellowknife
# Processing Record 19 of Set 3 | elliot
# Processing Record 20 of Set 3 | yanykurgan
# Processing Record 21 of Set 3 | nishinoomote
# Processing Record 22 of Set 3 | jefferson city
# Processing Record 23 of Set 3 | smirnykh
# Processing Record 24 of Set 3 | hassi messaoud
# Processing Record 25 of Set 3 | mana
# Processing Record 26 of Set 3 | newport
# Processing Record 27 of Set 3 | la sarre
# Processing Record 28 of Set 3 | st. john's
# Processing Record 29 of Set 3 | hawaiian paradise park
# Processing Record 30 of Set 3 | minbu
# Processing Record 31 of Set 3 | puerto armuelles
# Processing Record 32 of Set 3 | achinsk
# Processing Record 33 of Set 3 | ketchikan
# Processing Record 34 of Set 3 | keflavik
# Processing Record 35 of Set 3 | selfoss
# Processing Record 36 of Set 3 | college
# Processing Record 37 of Set 3 | tongren
# Processing Record 38 of Set 3 | georgetown
# Processing Record 39 of Set 3 | bo phloi
# Processing Record 40 of Set 3 | columbia
# Processing Record 41 of Set 3 | falenki
# Processing Record 42 of Set 3 | trincomalee
# Processing Record 43 of Set 3 | de haan
# Processing Record 44 of Set 3 | longyearbyen
# Processing Record 45 of Set 3 | mount pearl
# Processing Record 46 of Set 3 | pathein
# Processing Record 47 of Set 3 | tyler
# Processing Record 48 of Set 3 | san matias
# Processing Record 49 of Set 3 | jianshui
# Processing Record 0 of Set 4 | fort st. john
# Processing Record 1 of Set 4 | shwebo
# Processing Record 2 of Set 4 | nchelenge
# Processing Record 3 of Set 4 | vadso
# Processing Record 4 of Set 4 | touros
# Processing Record 5 of Set 4 | al jawf
# Processing Record 6 of Set 4 | san ignacio
# Processing Record 7 of Set 4 | areka
# Processing Record 8 of Set 4 | luderitz
# Processing Record 9 of Set 4 | afaahiti
# Processing Record 10 of Set 4 | ejura
# Processing Record 11 of Set 4 | arkhangel'sk
# Processing Record 12 of Set 4 | boise
# Processing Record 13 of Set 4 | prieska
# Processing Record 14 of Set 4 | vorkuta
# Processing Record 15 of Set 4 | carlsbad
# Processing Record 16 of Set 4 | al kharijah
# Processing Record 17 of Set 4 | lao cai
# Processing Record 18 of Set 4 | coahuayana de hidalgo
# Processing Record 19 of Set 4 | fort liberte
# Processing Record 20 of Set 4 | berdigestyakh
# Processing Record 21 of Set 4 | quellon
# Processing Record 22 of Set 4 | kulia village
# City not found. Skipping...
# Processing Record 23 of Set 4 | kodiak
# Processing Record 24 of Set 4 | hadibu
# Processing Record 25 of Set 4 | zavodoukovsk
# Processing Record 26 of Set 4 | rio grande
# Processing Record 27 of Set 4 | kalmunai
# Processing Record 28 of Set 4 | khilok
# Processing Record 29 of Set 4 | angaur state
# Processing Record 30 of Set 4 | anadyr
# Processing Record 31 of Set 4 | progreso
# Processing Record 32 of Set 4 | lerwick
# Processing Record 33 of Set 4 | happy valley-goose bay
# Processing Record 34 of Set 4 | toktogul
# Processing Record 35 of Set 4 | malindi
# Processing Record 36 of Set 4 | port alfred
# Processing Record 37 of Set 4 | nuku'alofa
# Processing Record 38 of Set 4 | leua
# Processing Record 39 of Set 4 | shiqian
# Processing Record 40 of Set 4 | kambove
# Processing Record 41 of Set 4 | niamtougou
# Processing Record 42 of Set 4 | westport
# Processing Record 43 of Set 4 | zhanaozen
# Processing Record 44 of Set 4 | gadzhiyevo
# Processing Record 45 of Set 4 | vingt cinq
# City not found. Skipping...
# Processing Record 46 of Set 4 | wang nam yen
# Processing Record 47 of Set 4 | molteno
# Processing Record 48 of Set 4 | tsetserleg
# Processing Record 49 of Set 4 | utrik
# Processing Record 0 of Set 5 | solleftea
# Processing Record 1 of Set 5 | mugia
# Processing Record 2 of Set 5 | n'zeto
# Processing Record 3 of Set 5 | vorgashor
# Processing Record 4 of Set 5 | turabah
# Processing Record 5 of Set 5 | comilla
# Processing Record 6 of Set 5 | acarau
# Processing Record 7 of Set 5 | fredericia
# Processing Record 8 of Set 5 | amahai
# Processing Record 9 of Set 5 | penzance
# Processing Record 10 of Set 5 | iquique
# Processing Record 11 of Set 5 | nova sintra
# Processing Record 12 of Set 5 | san pedro pochutla
# Processing Record 13 of Set 5 | lucea
# Processing Record 14 of Set 5 | el calafate
# Processing Record 15 of Set 5 | papao
# Processing Record 16 of Set 5 | rongelap
# Processing Record 17 of Set 5 | iskateley
# Processing Record 18 of Set 5 | sambava
# Processing Record 19 of Set 5 | hithadhoo
# Processing Record 20 of Set 5 | la gi
# Processing Record 21 of Set 5 | ujae
# Processing Record 22 of Set 5 | kailua-kona
# Processing Record 23 of Set 5 | bratsk
# Processing Record 24 of Set 5 | podporozh'ye
# Processing Record 25 of Set 5 | lebu
# Processing Record 26 of Set 5 | tingo maria
# Processing Record 27 of Set 5 | fortuna
# Processing Record 28 of Set 5 | namibe
# Processing Record 29 of Set 5 | ghanzi
# Processing Record 30 of Set 5 | ventspils
# Processing Record 31 of Set 5 | northam
# Processing Record 32 of Set 5 | manokwari
# Processing Record 33 of Set 5 | wailua homesteads
# Processing Record 34 of Set 5 | mahina
# Processing Record 35 of Set 5 | axim
# Processing Record 36 of Set 5 | tanhacu
# Processing Record 37 of Set 5 | gounou gaya
# Processing Record 38 of Set 5 | nuuk
# Processing Record 39 of Set 5 | roma
# Processing Record 40 of Set 5 | santa ana de yacuma
# Processing Record 41 of Set 5 | naze
# Processing Record 42 of Set 5 | kuraymah
# Processing Record 43 of Set 5 | khenifra
# Processing Record 44 of Set 5 | luganville
# Processing Record 45 of Set 5 | goundam
# Processing Record 46 of Set 5 | constantia
# Processing Record 47 of Set 5 | flying fish cove
# Processing Record 48 of Set 5 | altai
# Processing Record 49 of Set 5 | santa rosa del sur
# Processing Record 0 of Set 6 | port pirie
# Processing Record 1 of Set 6 | jogeva
# Processing Record 2 of Set 6 | topolobampo
# Processing Record 3 of Set 6 | sete lagoas
# Processing Record 4 of Set 6 | bredasdorp
# Processing Record 5 of Set 6 | kruisfontein
# Processing Record 6 of Set 6 | korfovskiy
# Processing Record 7 of Set 6 | chui
# Processing Record 8 of Set 6 | 'ain boucif
# Processing Record 9 of Set 6 | cedeira
# Processing Record 10 of Set 6 | bowen
# Processing Record 11 of Set 6 | grand-bassam
# Processing Record 12 of Set 6 | sisimiut
# Processing Record 13 of Set 6 | kirkwall
# Processing Record 14 of Set 6 | conceicao do araguaia
# Processing Record 15 of Set 6 | olyokminsk
# Processing Record 16 of Set 6 | worthington
# Processing Record 17 of Set 6 | taulaga
# Processing Record 18 of Set 6 | margate
# Processing Record 19 of Set 6 | lata
# Processing Record 20 of Set 6 | arauquita
# Processing Record 21 of Set 6 | kristiansund
# Processing Record 22 of Set 6 | kerikeri
# Processing Record 23 of Set 6 | taco pozo
# Processing Record 24 of Set 6 | alto piquiri
# Processing Record 25 of Set 6 | thunder bay
# Processing Record 26 of Set 6 | cobija
# Processing Record 27 of Set 6 | nguru
# Processing Record 28 of Set 6 | yung shue wan
# Processing Record 29 of Set 6 | taltal
# Processing Record 30 of Set 6 | at taj
# Processing Record 31 of Set 6 | lake wales
# Processing Record 32 of Set 6 | ust'-kulom
# Processing Record 33 of Set 6 | mao
# Processing Record 34 of Set 6 | inarajan village
# Processing Record 35 of Set 6 | acapulco de juarez
# Processing Record 36 of Set 6 | nidzica
# Processing Record 37 of Set 6 | assab
# Processing Record 38 of Set 6 | camana
# Processing Record 39 of Set 6 | punta arenas
# Processing Record 40 of Set 6 | labytnangi
# Processing Record 41 of Set 6 | bodo
# Processing Record 42 of Set 6 | sao felix do xingu
# Processing Record 43 of Set 6 | marakkanam
# Processing Record 44 of Set 6 | tionk essil
# Processing Record 45 of Set 6 | alindao
# Processing Record 46 of Set 6 | katsuren-haebaru
# Processing Record 47 of Set 6 | saudarkrokur
# Processing Record 48 of Set 6 | hilo
# Processing Record 49 of Set 6 | cabo san lucas
# Processing Record 0 of Set 7 | lysekil
# Processing Record 1 of Set 7 | petropavlovsk-kamchatsky
# Processing Record 2 of Set 7 | pirane
# Processing Record 3 of Set 7 | yagry
# City not found. Skipping...
# Processing Record 4 of Set 7 | new norfolk
# Processing Record 5 of Set 7 | golhisar
# Processing Record 6 of Set 7 | oamaru
# Processing Record 7 of Set 7 | jatai
# Processing Record 8 of Set 7 | harrai
# Processing Record 9 of Set 7 | pleinfeld
# Processing Record 10 of Set 7 | kovdor
# Processing Record 11 of Set 7 | morondava
# Processing Record 12 of Set 7 | dakhla
# Processing Record 13 of Set 7 | praia da vitoria
# Processing Record 14 of Set 7 | kolokani
# Processing Record 15 of Set 7 | humaita
# Processing Record 16 of Set 7 | gazojak
# Processing Record 17 of Set 7 | nea ionia
# Processing Record 18 of Set 7 | xunchang
# Processing Record 19 of Set 7 | guerrero negro
# Processing Record 20 of Set 7 | holualoa
# Processing Record 21 of Set 7 | alotau
# Processing Record 22 of Set 7 | pariaman
# Processing Record 23 of Set 7 | lompoc
# Processing Record 24 of Set 7 | yambio
# Processing Record 25 of Set 7 | hermanus
# Processing Record 26 of Set 7 | paita
# Processing Record 27 of Set 7 | bryne
# Processing Record 28 of Set 7 | boguchany
# Processing Record 29 of Set 7 | ataq
# Processing Record 30 of Set 7 | kilindoni
# Processing Record 31 of Set 7 | torghay
# Processing Record 32 of Set 7 | gunjur
# Processing Record 33 of Set 7 | aasiaat
# Processing Record 34 of Set 7 | ban tak
# Processing Record 35 of Set 7 | coquimbo
# Processing Record 36 of Set 7 | talcahuano
# Processing Record 37 of Set 7 | manistee
# Processing Record 38 of Set 7 | praia
# Processing Record 39 of Set 7 | tralee
# Processing Record 40 of Set 7 | tamanrasset
# Processing Record 41 of Set 7 | ardabil
# Processing Record 42 of Set 7 | constitucion
# Processing Record 43 of Set 7 | leh
# Processing Record 44 of Set 7 | kununurra
# Processing Record 45 of Set 7 | great falls
# Processing Record 46 of Set 7 | port augusta
# Processing Record 47 of Set 7 | saint-georges
# Processing Record 48 of Set 7 | atafu village
# Processing Record 49 of Set 7 | jhinjhak
# Processing Record 0 of Set 8 | caorle
# Processing Record 1 of Set 8 | okha
# Processing Record 2 of Set 8 | port lincoln
# Processing Record 3 of Set 8 | bayan nur
# City not found. Skipping...
# Processing Record 4 of Set 8 | ovruch
# Processing Record 5 of Set 8 | muzayri'
# City not found. Skipping...
# Processing Record 6 of Set 8 | nadi
# Processing Record 7 of Set 8 | bardai
# Processing Record 8 of Set 8 | codrington
# Processing Record 9 of Set 8 | rabo de peixe
# Processing Record 10 of Set 8 | zhezqazghan
# Processing Record 11 of Set 8 | kabare
# Processing Record 12 of Set 8 | borogontsy
# Processing Record 13 of Set 8 | itoman
# Processing Record 14 of Set 8 | santa ana
# Processing Record 15 of Set 8 | ust-nera
# Processing Record 16 of Set 8 | atar
# Processing Record 17 of Set 8 | patterson
# Processing Record 18 of Set 8 | visakhapatnam
# Processing Record 19 of Set 8 | vernon
# Processing Record 20 of Set 8 | byron bay
# Processing Record 21 of Set 8 | bhamo
# Processing Record 22 of Set 8 | krasnozerskoye
# Processing Record 23 of Set 8 | sarmiento
# Processing Record 24 of Set 8 | pisco
# Processing Record 25 of Set 8 | puerto real
# Processing Record 26 of Set 8 | mahibadhoo
# Processing Record 27 of Set 8 | kirakira
# Processing Record 28 of Set 8 | pointe aux piments
# Processing Record 29 of Set 8 | huarmey
# Processing Record 30 of Set 8 | selebi-phikwe
# Processing Record 31 of Set 8 | arno
# Processing Record 32 of Set 8 | mangrol
# Processing Record 33 of Set 8 | al ghayzah
# Processing Record 34 of Set 8 | pizarro
# Processing Record 35 of Set 8 | riviere-du-loup
# Processing Record 36 of Set 8 | luorong
# Processing Record 37 of Set 8 | nova vicosa
# Processing Record 38 of Set 8 | conception bay south
# Processing Record 39 of Set 8 | champerico
# Processing Record 40 of Set 8 | farsan
# Processing Record 41 of Set 8 | crane
# Processing Record 42 of Set 8 | dar naim
# City not found. Skipping...
# Processing Record 43 of Set 8 | lubang
# Processing Record 44 of Set 8 | shimoda
# Processing Record 45 of Set 8 | dryden
# Processing Record 46 of Set 8 | korla
# Processing Record 47 of Set 8 | carnarvon
# Processing Record 48 of Set 8 | diadi
# Processing Record 49 of Set 8 | cancun
# Processing Record 0 of Set 9 | kudahuvadhoo
# Processing Record 1 of Set 9 | jiazi
# Processing Record 2 of Set 9 | solnechnyy
# Processing Record 3 of Set 9 | isla vista
# Processing Record 4 of Set 9 | belle fourche
# Processing Record 5 of Set 9 | foca
# Processing Record 6 of Set 9 | birnin kudu
# Processing Record 7 of Set 9 | sao raimundo nonato
# Processing Record 8 of Set 9 | salina
# Processing Record 9 of Set 9 | daru
# Processing Record 10 of Set 9 | charlotte amalie
# Processing Record 11 of Set 9 | tabas
# Processing Record 12 of Set 9 | anloga
# Processing Record 13 of Set 9 | hamilton
# Processing Record 14 of Set 9 | yoichi
# Processing Record 15 of Set 9 | oudewater
# Processing Record 16 of Set 9 | kristinestad
# Processing Record 17 of Set 9 | el granada
# Processing Record 18 of Set 9 | vila franca do campo
# Processing Record 19 of Set 9 | maiurno
# Processing Record 20 of Set 9 | aljezur
# Processing Record 21 of Set 9 | saldanha
# Processing Record 22 of Set 9 | maubara
# City not found. Skipping...
# Processing Record 23 of Set 9 | siwa oasis
# Processing Record 24 of Set 9 | kolonia town
# Processing Record 25 of Set 9 | enewetak
# Processing Record 26 of Set 9 | mejit
# Processing Record 27 of Set 9 | ghormach
# Processing Record 28 of Set 9 | tromso
# Processing Record 29 of Set 9 | kamensk-ural'skiy
# Processing Record 30 of Set 9 | igrim
# Processing Record 31 of Set 9 | bonthe
# Processing Record 32 of Set 9 | alpena
# Processing Record 33 of Set 9 | las tablas
# Processing Record 34 of Set 9 | mount isa
# Processing Record 35 of Set 9 | lospalos
# Processing Record 36 of Set 9 | qa'en
# Processing Record 37 of Set 9 | clodomira
# Processing Record 38 of Set 9 | gislaved
# Processing Record 39 of Set 9 | leer
# Processing Record 40 of Set 9 | fruitland
# Processing Record 41 of Set 9 | magistral'nyy
# Processing Record 42 of Set 9 | ola
# Processing Record 43 of Set 9 | chibougamau
# Processing Record 44 of Set 9 | dunedin
# Processing Record 45 of Set 9 | mme-bafumen
# Processing Record 46 of Set 9 | lishui
# Processing Record 47 of Set 9 | takoradi
# Processing Record 48 of Set 9 | kenai
# Processing Record 49 of Set 9 | vila velha
# Processing Record 0 of Set 10 | hayma'
# City not found. Skipping...
# Processing Record 1 of Set 10 | bathsheba
# Processing Record 2 of Set 10 | barra de santo antonio
# Processing Record 3 of Set 10 | kangding
# Processing Record 4 of Set 10 | szczytno
# Processing Record 5 of Set 10 | tazacorte
# Processing Record 6 of Set 10 | tamala
# Processing Record 7 of Set 10 | kone
# Processing Record 8 of Set 10 | great bend
# Processing Record 9 of Set 10 | ouesso
# Processing Record 10 of Set 10 | aflou
# Processing Record 11 of Set 10 | mount gambier
# Processing Record 12 of Set 10 | usinsk
# Processing Record 13 of Set 10 | ranikhet
# Processing Record 14 of Set 10 | colonel hill
# Processing Record 15 of Set 10 | zuenoula
# Processing Record 16 of Set 10 | santa luzia
# Processing Record 17 of Set 10 | chimichagua
# Processing Record 18 of Set 10 | muisne
# Processing Record 19 of Set 10 | coronel suarez
# Processing Record 20 of Set 10 | quelimane
# Processing Record 21 of Set 10 | saint-pierre
# Processing Record 22 of Set 10 | choibalsan
# Processing Record 23 of Set 10 | yarmouth
# Processing Record 24 of Set 10 | la passe
# Processing Record 25 of Set 10 | nizhnyaya poyma
# Processing Record 26 of Set 10 | bubaque
# Processing Record 27 of Set 10 | kalyandurg
# Processing Record 28 of Set 10 | gannan
# Processing Record 29 of Set 10 | warwick
# Processing Record 30 of Set 10 | puerto cabezas
# Processing Record 31 of Set 10 | quesnel
# Processing Record 32 of Set 10 | saint-philippe
# Processing Record 33 of Set 10 | howard springs
# Processing Record 34 of Set 10 | murzuq
# Processing Record 35 of Set 10 | mwanza
# Processing Record 36 of Set 10 | sonsorol village
# City not found. Skipping...
# Processing Record 37 of Set 10 | yeppoon
# Processing Record 38 of Set 10 | khandyga
# Processing Record 39 of Set 10 | isnos
# Processing Record 40 of Set 10 | sovetskaya gavan'
# Processing Record 41 of Set 10 | waiuku
# Processing Record 42 of Set 10 | mossel bay
# Processing Record 43 of Set 10 | devinuwara
# City not found. Skipping...
# Processing Record 44 of Set 10 | san antonio de pale
# Processing Record 45 of Set 10 | vilhena
# Processing Record 46 of Set 10 | luau
# Processing Record 47 of Set 10 | trapani
# Processing Record 48 of Set 10 | trelew
# Processing Record 49 of Set 10 | kourou
# Processing Record 0 of Set 11 | turpan
# Processing Record 1 of Set 11 | al qaryatayn
# Processing Record 2 of Set 11 | cill airne
# Processing Record 3 of Set 11 | shetpe
# Processing Record 4 of Set 11 | bamboo flat
# Processing Record 5 of Set 11 | antsiranana
# Processing Record 6 of Set 11 | pacific grove
# Processing Record 7 of Set 11 | tubarjal
# Processing Record 8 of Set 11 | terenozek
# Processing Record 9 of Set 11 | as sulayyil
# Processing Record 10 of Set 11 | klimovo
# Processing Record 11 of Set 11 | kittila
# Processing Record 12 of Set 11 | pontian kechil
# Processing Record 13 of Set 11 | ciudad lazaro cardenas
# Processing Record 14 of Set 11 | lamu
# Processing Record 15 of Set 11 | saint-francois
# Processing Record 16 of Set 11 | ibshaway
# Processing Record 17 of Set 11 | garachico
# Processing Record 18 of Set 11 | mahendragarh
# Processing Record 19 of Set 11 | al hilaliyya
# Processing Record 20 of Set 11 | zhangye
# Processing Record 21 of Set 11 | muynoq
# Processing Record 22 of Set 11 | dravograd
# Processing Record 23 of Set 11 | suva
# Processing Record 24 of Set 11 | ningbo
# Processing Record 25 of Set 11 | vila do maio
# Processing Record 26 of Set 11 | changwon
# Processing Record 27 of Set 11 | yanam
# Processing Record 28 of Set 11 | manaus
# Processing Record 29 of Set 11 | cockburn town
# Processing Record 30 of Set 11 | filadelfia
# Processing Record 31 of Set 11 | portlaoise
# Processing Record 32 of Set 11 | contai
# Processing Record 33 of Set 11 | mitu
# Processing Record 34 of Set 11 | severo-vostotchnyi bank
# Processing Record 35 of Set 11 | iguape
# Processing Record 36 of Set 11 | reichshoffen
# Processing Record 37 of Set 11 | khonsa
# Processing Record 38 of Set 11 | huilong
# Processing Record 39 of Set 11 | itaituba
# Processing Record 40 of Set 11 | oranjemund
# Processing Record 41 of Set 11 | nantucket
# Processing Record 42 of Set 11 | yuzhno-kurilsk
# Processing Record 43 of Set 11 | chuguyevka
# Processing Record 44 of Set 11 | idri
# Processing Record 45 of Set 11 | la'ie
# Processing Record 46 of Set 11 | batie
# Processing Record 47 of Set 11 | coronel dorrego
# Processing Record 48 of Set 11 | bengkulu
# Processing Record 49 of Set 11 | necochea
# Processing Record 0 of Set 12 | lengshuitan
# Processing Record 1 of Set 12 | kogalym
# Processing Record 2 of Set 12 | kipushi
# Processing Record 3 of Set 12 | xilin hot
# Processing Record 4 of Set 12 | matthew town
# Processing Record 5 of Set 12 | tchollire
# Processing Record 6 of Set 12 | santiago
# Processing Record 7 of Set 12 | medford
# Processing Record 8 of Set 12 | nar'yan-mar
# Processing Record 9 of Set 12 | egilsstadir
# Processing Record 10 of Set 12 | broken hill
# Processing Record 11 of Set 12 | barakani
# Processing Record 12 of Set 12 | tweed heads
# Processing Record 13 of Set 12 | serhiyivka
# Processing Record 14 of Set 12 | paragominas
# Processing Record 15 of Set 12 | sechura
# Processing Record 16 of Set 12 | twon-brass
# Processing Record 17 of Set 12 | djibo
# Processing Record 18 of Set 12 | nowogard
# Processing Record 19 of Set 12 | selkirk
# Processing Record 20 of Set 12 | medicine hat
# Processing Record 21 of Set 12 | kulhudhuffushi
# Processing Record 22 of Set 12 | kisanga
# Processing Record 23 of Set 12 | kuching
# Processing Record 24 of Set 12 | akot
# Processing Record 25 of Set 12 | concepcion del oro
# Processing Record 26 of Set 12 | sola
# Processing Record 27 of Set 12 | la romana
# Processing Record 28 of Set 12 | namtsy
# Processing Record 29 of Set 12 | hauterive
# Processing Record 30 of Set 12 | beloyarskiy
# Processing Record 31 of Set 12 | kuusamo
# Processing Record 32 of Set 12 | katabu
# Processing Record 33 of Set 12 | dowagiac
# Processing Record 34 of Set 12 | shahecheng
# Processing Record 35 of Set 12 | agadez
# Processing Record 36 of Set 12 | irymple
# Processing Record 37 of Set 12 | dire
# Processing Record 38 of Set 12 | zwevegem
# Processing Record 39 of Set 12 | yemetsk
# Processing Record 40 of Set 12 | cargados carajos
# City not found. Skipping...
# Processing Record 41 of Set 12 | cooma
# Processing Record 42 of Set 12 | uyuni
# Processing Record 43 of Set 12 | wulingyuan
# Processing Record 44 of Set 12 | torbat-e heydariyeh
# Processing Record 45 of Set 12 | nizhneangarsk
# Processing Record 46 of Set 12 | charters towers
# Processing Record 47 of Set 12 | san-pedro
# Processing Record 48 of Set 12 | strelka
# Processing Record 49 of Set 12 | kapa'a
# Processing Record 0 of Set 13 | weno
# Processing Record 1 of Set 13 | arraial do cabo
# Processing Record 2 of Set 13 | aden
# Processing Record 3 of Set 13 | baiti
# Processing Record 4 of Set 13 | gornozavodsk
# Processing Record 5 of Set 13 | corner brook
# Processing Record 6 of Set 13 | nieuw amsterdam
# Processing Record 7 of Set 13 | jabor
# Processing Record 8 of Set 13 | ta`u
# Processing Record 9 of Set 13 | prince rupert
# Processing Record 10 of Set 13 | yerofey pavlovich
# Processing Record 11 of Set 13 | antofagasta
# Processing Record 12 of Set 13 | sinop
# Processing Record 13 of Set 13 | kuqa
# Processing Record 14 of Set 13 | queenstown
# Processing Record 15 of Set 13 | noumea
# Processing Record 16 of Set 13 | pontes e lacerda
# Processing Record 17 of Set 13 | tadine
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          598
# Lat           598
# Lng           598
# Max Temp      598
# Humidity      598
# Cloudiness    598
# Wind Speed    598
# Country       598
# Date          598
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#                           City      Lat      Lng  Max Temp  Humidity  \
# 0                       palmer  42.1584 -72.3287     23.88        82
# 1                      adampur  31.4328  75.7175     26.86        90
# 2  edinburgh of the seven seas -37.0676 -12.3116     11.75        58
# 3                      colonia  50.9333   6.9500     19.90        88
# 4                      iqaluit  63.7506 -68.5145      7.85        61
#
#    Cloudiness  Wind Speed Country        Date
# 0         100        3.60      US  1722471379
# 1         100        6.29      IN  1722471380
# 2          15        8.33      SH  1722471381
# 3           0        1.03      DE  1722471206
# 4          20        2.57      CA  1722471384

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                                 City      Lat      Lng  Max Temp  Humidity  \
# City_ID
# 0                             palmer  42.1584 -72.3287     23.88        82
# 1                            adampur  31.4328  75.7175     26.86        90
# 2        edinburgh of the seven seas -37.0676 -12.3116     11.75        58
# 3                            colonia  50.9333   6.9500     19.90        88
# 4                            iqaluit  63.7506 -68.5145      7.85        61
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 0               100        3.60      US  1722471379
# 1               100        6.29      IN  1722471380
# 2                15        8.33      SH  1722471381
# 3                 0        1.03      DE  1722471206
# 4                20        2.57      CA  1722471384

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(city_data_df["Lat"], city_data_df["Max Temp"], edgecolors="black", linewidths=1, marker="o", alpha=0.8)
plt.title("Latitude vs. Max Temp (2024-07-31)")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (C)")
plt.grid(True)

# Incorporate the other graph properties
# YOUR CODE HERE
plt.xticks(np.arange(-60, 100, step=20))
plt.yticks(np.arange(0, max(city_data_df["Max Temp"])+10, step=10))
plt.tight_layout()

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(city_data_df["Lat"], city_data_df["Humidity"], edgecolors="black", linewidths=1, marker="o", alpha=0.8)
plt.title("Latitude vs. Humidity (2024-07-31)")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.grid(True)

# Incorporate the other graph properties
plt.xticks(np.arange(-60, 100, step=20))
plt.yticks(np.arange(0, max(city_data_df["Humidity"])+10, step=20))

plt.tight_layout()
# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
# YOUR CODE HERE
plt.scatter(city_data_df["Lat"], city_data_df["Cloudiness"], edgecolors="black", linewidths=1, marker="o", alpha=0.8)
plt.title("Latitude vs. Cloudiness (2024-07-31)")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid(True)

# Incorporate the other graph properties
# YOUR CODE HERE
plt.xticks(np.arange(-60, 100, step=20))
plt.yticks(np.arange(0, max(city_data_df["Cloudiness"])+10, step=20))
plt.tight_layout()

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
# YOUR CODE HERE
plt.scatter(city_data_df["Lat"], city_data_df["Wind Speed"], edgecolors="black", linewidths=1, marker="o", alpha=0.8)
plt.title("Latitude vs. Wind Speed (2024-07-31)")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (m/s)")
plt.grid(True)

# Incorporate the other graph properties
# YOUR CODE HERE
plt.xticks(np.arange(-60, 100, step=20))
plt.yticks(np.arange(0, 16, step=2))
plt.tight_layout()

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
# YOUR CODE HERE
def plot_linear_regression(x_values, y_values, title, text_coordinates, ylabel, plot_filename):
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    regress_values = x_values * slope + intercept
    line_eq = f"y = {round(slope,2)}x + {round(intercept,2)}"
    r_squared = rvalue**2
    print(f"The r^2 value is: {r_squared}")
    plt.scatter(x_values, y_values)
    plt.plot(x_values, regress_values, "r-")
    plt.annotate(line_eq, text_coordinates, fontsize=15, color="red")
    plt.title(title)
    plt.xlabel("Latitude")
    plt.ylabel(ylabel)
    # plt.grid(True)
    plt.savefig(plot_filename)
    plt.show()
    
    # print(f"The r^2 value is: {r_squared:.f}")

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
# YOUR CODE HERE
northern_hemi_df = city_data_df[city_data_df["Lat"] >= 0]
# Display sample data
northern_hemi_df.head()
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0         palmer  42.1584  -72.3287     23.88        82         100
# 1        adampur  31.4328   75.7175     26.86        90         100
# 3        colonia  50.9333    6.9500     19.90        88           0
# 4        iqaluit  63.7506  -68.5145      7.85        61          20
# 7           miri   4.4148  114.0089     30.08        84          20
#
#          Wind Speed Country        Date
# City_ID
# 0              3.60      US  1722471379
# 1              6.29      IN  1722471380
# 3              1.03      DE  1722471206
# 4              2.57      CA  1722471384
# 7              2.06      MY  1722471388

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
# YOUR CODE HERE
southern_hemi_df = city_data_df[city_data_df["Lat"] < 0]
# Display sample data
southern_hemi_df.head()
# Out:
#                                 City      Lat       Lng  Max Temp  Humidity  \
# City_ID
# 2        edinburgh of the seven seas -37.0676  -12.3116     11.75        58
# 5                      port mathurin -19.6833   63.4167     22.57        79
# 6                           waitangi -43.9535 -176.5597      9.90        86
# 9                          adamstown -25.0660 -130.1015     22.27        88
# 13           puerto baquerizo moreno  -0.9000  -89.6000     20.10        91
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 2                15        8.33      SH  1722471381
# 5                43        6.89      MU  1722471385
# 6                88        2.24      NZ  1722471386
# 9                12        9.27      PN  1722471390
# 13               68        6.81      EC  1722471397

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
# YOUR CODE HERE
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Max Temp"]
plot_linear_regression(x_values, y_values,"Latitude vs Max Temp (C)", (10, -20), "Max Temp (C)", "output_data/fig5.png")
# Out:
# The r^2 value is: 0.4506237535323493

# %%
# Linear regression on Southern Hemisphere
# YOUR CODE HERE
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Max Temp"]
plot_linear_regression(x_values, y_values, "Latitude vs Max Temp (C)", (-50, 30), "Max Temp (C)", "output_data/Fig6.png")
# Out:
# The r^2 value is: 0.6778490891631709

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Humidity"]
plot_linear_regression(x_values, y_values, "Latitude vs Humidity", (10, 40), "Humidity (%)", "output_data/Fig7.png")
# Out:
# The r^2 value is: 0.004015083429178578

# %%
# Southern Hemisphere
# YOUR CODE HERE
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Humidity"]
plot_linear_regression(x_values, y_values, "Latitude vs Humidity", (-50, 40), "Humidity (%)", "output_data/Fig8.png")
# Out:
# The r^2 value is: 0.02483954574095092

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Cloudiness"]
plot_linear_regression(x_values, y_values, "Latitude vs Cloudiness", (10, 40), "Cloudiness (%)", "output_data/Fig9.png")
# Out:
# The r^2 value is: 0.006592696354387207

# %%
# Southern Hemisphere
# YOUR CODE HERE
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Cloudiness"]
plot_linear_regression(x_values, y_values, "Latitude vs Cloudiness", (10, 40), "Cloudiness (%)", "output_data/Fig10.png")
# Out:
# The r^2 value is: 0.01452157462163792

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Wind Speed"]
plot_linear_regression(x_values, y_values, "Latitude vs Wind Speed", (10, 12), "Wind Speed (m/s)", "output_data/Fig11.png")
# Out:
# The r^2 value is: 0.008102703562332956

# %%
# Southern Hemisphere
# YOUR CODE HERE
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Wind Speed"]
plot_linear_regression(x_values, y_values, "Latitude vs Wind Speed", (10, 12), "Wind Speed (m/s)", "output_data/Fig12.png")
# Out:
# The r^2 value is: 0.01315756638552443

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE
