# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name

    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 612

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "https://api.openweathermap.org/data/2.5/weather?appid=" + weather_api_key + "&units=metric"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = url + "&q=" + city

    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_date = city_weather['dt']

        # Append the City information into city_data list
        city_data.append({"City": city,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

    # pause to avoid rate limiting
    time.sleep(1)

# Indicate that Data Loading is complete
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | adamstown
# Processing Record 2 of Set 1 | saldanha
# Processing Record 3 of Set 1 | champerico
# Processing Record 4 of Set 1 | bethel
# Processing Record 5 of Set 1 | pitimbu
# Processing Record 6 of Set 1 | longyearbyen
# Processing Record 7 of Set 1 | edinburgh of the seven seas
# Processing Record 8 of Set 1 | brownwood
# Processing Record 9 of Set 1 | pacific grove
# Processing Record 10 of Set 1 | invercargill
# Processing Record 11 of Set 1 | valparaiso
# Processing Record 12 of Set 1 | yellowknife
# Processing Record 13 of Set 1 | kruisfontein
# Processing Record 14 of Set 1 | la seu d'urgell
# Processing Record 15 of Set 1 | igarka
# Processing Record 16 of Set 1 | wailua homesteads
# Processing Record 17 of Set 1 | soio
# Processing Record 18 of Set 1 | arraial do cabo
# Processing Record 19 of Set 1 | vorgashor
# Processing Record 20 of Set 1 | mukalla
# Processing Record 21 of Set 1 | puerto ayora
# Processing Record 22 of Set 1 | balabac
# Processing Record 23 of Set 1 | jamestown
# Processing Record 24 of Set 1 | port-aux-francais
# Processing Record 25 of Set 1 | grytviken
# Processing Record 26 of Set 1 | zamania
# Processing Record 27 of Set 1 | whitehorse
# Processing Record 28 of Set 1 | puerto leguizamo
# Processing Record 29 of Set 1 | woodlake
# Processing Record 30 of Set 1 | hermanus
# Processing Record 31 of Set 1 | vadso
# Processing Record 32 of Set 1 | isafjordur
# Processing Record 33 of Set 1 | hamilton
# Processing Record 34 of Set 1 | ahau
# City not found. Skipping...
# Processing Record 35 of Set 1 | waitangi
# Processing Record 36 of Set 1 | robbah
# Processing Record 37 of Set 1 | albany
# Processing Record 38 of Set 1 | ribeira grande
# Processing Record 39 of Set 1 | hammerfest
# Processing Record 40 of Set 1 | naze
# Processing Record 41 of Set 1 | itaueira
# Processing Record 42 of Set 1 | horta
# Processing Record 43 of Set 1 | papatowai
# Processing Record 44 of Set 1 | nemuro
# Processing Record 45 of Set 1 | lazarevskoye
# Processing Record 46 of Set 1 | puerto natales
# Processing Record 47 of Set 1 | port saint john's
# Processing Record 48 of Set 1 | indianola
# Processing Record 49 of Set 1 | moroni
# Processing Record 50 of Set 1 | ascension
# Processing Record 0 of Set 2 | labytnangi
# Processing Record 1 of Set 2 | klyuchi
# Processing Record 2 of Set 2 | taro
# Processing Record 3 of Set 2 | happy valley-goose bay
# Processing Record 4 of Set 2 | warner robins
# Processing Record 5 of Set 2 | hithadhoo
# Processing Record 6 of Set 2 | tomatlan
# Processing Record 7 of Set 2 | caister-on-sea
# Processing Record 8 of Set 2 | arkhangel'sk
# Processing Record 9 of Set 2 | blackmans bay
# Processing Record 10 of Set 2 | leua
# Processing Record 11 of Set 2 | bilibino
# Processing Record 12 of Set 2 | belgrade
# Processing Record 13 of Set 2 | olinda
# Processing Record 14 of Set 2 | zhengjiatun
# Processing Record 15 of Set 2 | talnakh
# Processing Record 16 of Set 2 | iqaluit
# Processing Record 17 of Set 2 | kudat
# Processing Record 18 of Set 2 | 'ohonua
# City not found. Skipping...
# Processing Record 19 of Set 2 | avarua
# Processing Record 20 of Set 2 | san luis de la loma
# Processing Record 21 of Set 2 | bardai
# Processing Record 22 of Set 2 | tolanaro
# Processing Record 23 of Set 2 | afaahiti
# Processing Record 24 of Set 2 | sisimiut
# Processing Record 25 of Set 2 | puerto baquerizo moreno
# Processing Record 26 of Set 2 | ust-nera
# Processing Record 27 of Set 2 | island harbour
# Processing Record 28 of Set 2 | utrik
# Processing Record 29 of Set 2 | cooma
# Processing Record 30 of Set 2 | chonchi
# Processing Record 31 of Set 2 | port hedland
# Processing Record 32 of Set 2 | kayyerkan
# Processing Record 33 of Set 2 | carnarvon
# Processing Record 34 of Set 2 | olonkinbyen
# Processing Record 35 of Set 2 | mwinilunga
# Processing Record 36 of Set 2 | bredasdorp
# Processing Record 37 of Set 2 | totskoye
# Processing Record 38 of Set 2 | atafu village
# Processing Record 39 of Set 2 | coxim
# Processing Record 40 of Set 2 | mahanoro
# Processing Record 41 of Set 2 | piti village
# Processing Record 42 of Set 2 | vengerovo
# Processing Record 43 of Set 2 | vilyuchinsk
# Processing Record 44 of Set 2 | st. john's
# Processing Record 45 of Set 2 | college
# Processing Record 46 of Set 2 | taiohae
# City not found. Skipping...
# Processing Record 47 of Set 2 | kincardine
# Processing Record 48 of Set 2 | tiksi
# Processing Record 49 of Set 2 | hotan
# Processing Record 0 of Set 3 | qaqortoq
# Processing Record 1 of Set 3 | touros
# Processing Record 2 of Set 3 | aasiaat
# Processing Record 3 of Set 3 | xanxere
# Processing Record 4 of Set 3 | khandyga
# Processing Record 5 of Set 3 | udachny
# Processing Record 6 of Set 3 | polyarnyy
# Processing Record 7 of Set 3 | isabela
# Processing Record 8 of Set 3 | beau vallon
# Processing Record 9 of Set 3 | hovd
# Processing Record 10 of Set 3 | kill devil hills
# Processing Record 11 of Set 3 | ulladulla
# Processing Record 12 of Set 3 | ushuaia
# Processing Record 13 of Set 3 | baoqing
# Processing Record 14 of Set 3 | fort bragg
# Processing Record 15 of Set 3 | lihue
# Processing Record 16 of Set 3 | mount gambier
# Processing Record 17 of Set 3 | pindushi
# Processing Record 18 of Set 3 | georgetown
# Processing Record 19 of Set 3 | karasburg
# Processing Record 20 of Set 3 | alotau
# Processing Record 21 of Set 3 | nadi
# Processing Record 22 of Set 3 | aykol
# Processing Record 23 of Set 3 | sola
# Processing Record 24 of Set 3 | thompson
# Processing Record 25 of Set 3 | withernsea
# Processing Record 26 of Set 3 | keflavik
# Processing Record 27 of Set 3 | margaret river
# Processing Record 28 of Set 3 | mar del plata
# Processing Record 29 of Set 3 | kargil
# Processing Record 30 of Set 3 | hihifo
# City not found. Skipping...
# Processing Record 31 of Set 3 | tofol
# Processing Record 32 of Set 3 | howard springs
# Processing Record 33 of Set 3 | kani keli
# Processing Record 34 of Set 3 | gizo
# Processing Record 35 of Set 3 | vila franca do campo
# Processing Record 36 of Set 3 | vorkuta
# Processing Record 37 of Set 3 | dudinka
# Processing Record 38 of Set 3 | pangai
# Processing Record 39 of Set 3 | wilson
# Processing Record 40 of Set 3 | saipan
# Processing Record 41 of Set 3 | kerikeri
# Processing Record 42 of Set 3 | yuzhno-kurilsk
# Processing Record 43 of Set 3 | punta arenas
# Processing Record 44 of Set 3 | morinville
# Processing Record 45 of Set 3 | ilulissat
# Processing Record 46 of Set 3 | gulf park estates
# Processing Record 47 of Set 3 | kununurra
# Processing Record 48 of Set 3 | vodnyy
# Processing Record 49 of Set 3 | coquimbo
# Processing Record 0 of Set 4 | kurmuk
# Processing Record 1 of Set 4 | hawaiian paradise park
# Processing Record 2 of Set 4 | port mathurin
# Processing Record 3 of Set 4 | uturoa
# Processing Record 4 of Set 4 | laza
# Processing Record 5 of Set 4 | gwadar
# Processing Record 6 of Set 4 | paita
# Processing Record 7 of Set 4 | egilsstadir
# Processing Record 8 of Set 4 | ixmiquilpan
# Processing Record 9 of Set 4 | kapa'a
# Processing Record 10 of Set 4 | grantsville
# Processing Record 11 of Set 4 | takoradi
# Processing Record 12 of Set 4 | kimbe
# Processing Record 13 of Set 4 | boguchany
# Processing Record 14 of Set 4 | bukama
# Processing Record 15 of Set 4 | port lincoln
# Processing Record 16 of Set 4 | illizi
# Processing Record 17 of Set 4 | jerada
# Processing Record 18 of Set 4 | butte
# Processing Record 19 of Set 4 | pekan
# Processing Record 20 of Set 4 | lulea
# Processing Record 21 of Set 4 | tranovaho
# City not found. Skipping...
# Processing Record 22 of Set 4 | starobaltachevo
# Processing Record 23 of Set 4 | saint-pierre
# Processing Record 24 of Set 4 | neiafu
# Processing Record 25 of Set 4 | russkaya polyana
# Processing Record 26 of Set 4 | vershino-darasunskiy
# Processing Record 27 of Set 4 | uacu cungo
# Processing Record 28 of Set 4 | zavodskoy
# Processing Record 29 of Set 4 | isiro
# Processing Record 30 of Set 4 | cromer
# Processing Record 31 of Set 4 | walvis bay
# Processing Record 32 of Set 4 | musay'id
# City not found. Skipping...
# Processing Record 33 of Set 4 | kenora
# Processing Record 34 of Set 4 | kotido
# Processing Record 35 of Set 4 | kilindoni
# Processing Record 36 of Set 4 | el tigre
# Processing Record 37 of Set 4 | lompoc
# Processing Record 38 of Set 4 | gallivare
# City not found. Skipping...
# Processing Record 39 of Set 4 | west island
# Processing Record 40 of Set 4 | mabamba
# Processing Record 41 of Set 4 | oamaru
# Processing Record 42 of Set 4 | khetia
# Processing Record 43 of Set 4 | east wenatchee bench
# Processing Record 44 of Set 4 | kodiak
# Processing Record 45 of Set 4 | kifri
# Processing Record 46 of Set 4 | vidin
# Processing Record 47 of Set 4 | harper
# Processing Record 48 of Set 4 | meizhou
# Processing Record 49 of Set 4 | dame-marie
# Processing Record 0 of Set 5 | pangody
# Processing Record 1 of Set 5 | sao joao da barra
# Processing Record 2 of Set 5 | grand-bassam
# Processing Record 3 of Set 5 | kangaba
# Processing Record 4 of Set 5 | waitara
# Processing Record 5 of Set 5 | remire-montjoly
# Processing Record 6 of Set 5 | lorengau
# Processing Record 7 of Set 5 | mount pearl
# Processing Record 8 of Set 5 | rawson
# Processing Record 9 of Set 5 | weno
# Processing Record 10 of Set 5 | yangor
# City not found. Skipping...
# Processing Record 11 of Set 5 | lagoa
# Processing Record 12 of Set 5 | saint-francois
# Processing Record 13 of Set 5 | jayapura
# Processing Record 14 of Set 5 | callao
# Processing Record 15 of Set 5 | nova sintra
# Processing Record 16 of Set 5 | kingston
# Processing Record 17 of Set 5 | babatngon
# Processing Record 18 of Set 5 | kingscliff
# Processing Record 19 of Set 5 | settat
# Processing Record 20 of Set 5 | anadyr
# Processing Record 21 of Set 5 | la ronge
# Processing Record 22 of Set 5 | mayna
# Processing Record 23 of Set 5 | yanam
# Processing Record 24 of Set 5 | kitakami
# Processing Record 25 of Set 5 | aq qayeh
# City not found. Skipping...
# Processing Record 26 of Set 5 | lahij
# Processing Record 27 of Set 5 | san jose del guaviare
# Processing Record 28 of Set 5 | klamath falls
# Processing Record 29 of Set 5 | gaiman
# Processing Record 30 of Set 5 | zalari
# Processing Record 31 of Set 5 | changji
# Processing Record 32 of Set 5 | codrington
# Processing Record 33 of Set 5 | salaqi
# Processing Record 34 of Set 5 | korsakov
# Processing Record 35 of Set 5 | broome
# Processing Record 36 of Set 5 | puerto san carlos
# City not found. Skipping...
# Processing Record 37 of Set 5 | clinton
# Processing Record 38 of Set 5 | srikakulam
# Processing Record 39 of Set 5 | hadibu
# Processing Record 40 of Set 5 | katsuura
# Processing Record 41 of Set 5 | prince rupert
# Processing Record 42 of Set 5 | jesus maria garza
# City not found. Skipping...
# Processing Record 43 of Set 5 | antsiranana
# Processing Record 44 of Set 5 | barra
# Processing Record 45 of Set 5 | altay
# Processing Record 46 of Set 5 | biltine
# Processing Record 47 of Set 5 | mogadishu
# Processing Record 48 of Set 5 | mahina
# Processing Record 49 of Set 5 | dadonghai
# City not found. Skipping...
# Processing Record 0 of Set 6 | grand falls-windsor
# Processing Record 1 of Set 6 | haiku-pauwela
# Processing Record 2 of Set 6 | kittila
# Processing Record 3 of Set 6 | komyshuvakha
# Processing Record 4 of Set 6 | sitka
# Processing Record 5 of Set 6 | leh
# Processing Record 6 of Set 6 | constantia
# Processing Record 7 of Set 6 | devinuwara
# City not found. Skipping...
# Processing Record 8 of Set 6 | stanley
# Processing Record 9 of Set 6 | lautoka
# Processing Record 10 of Set 6 | howrah
# Processing Record 11 of Set 6 | salinas
# Processing Record 12 of Set 6 | o rosal
# Processing Record 13 of Set 6 | tindouf
# Processing Record 14 of Set 6 | port elizabeth
# Processing Record 15 of Set 6 | intendente alvear
# Processing Record 16 of Set 6 | revda
# Processing Record 17 of Set 6 | colares
# Processing Record 18 of Set 6 | shibirghan
# Processing Record 19 of Set 6 | manta
# Processing Record 20 of Set 6 | kem'
# Processing Record 21 of Set 6 | colonia
# Processing Record 22 of Set 6 | kupang
# Processing Record 23 of Set 6 | berbera
# Processing Record 24 of Set 6 | laguna
# Processing Record 25 of Set 6 | east london
# Processing Record 26 of Set 6 | mirnyy
# Processing Record 27 of Set 6 | olyokminsk
# Processing Record 28 of Set 6 | labrador city
# Processing Record 29 of Set 6 | bhawana
# Processing Record 30 of Set 6 | moanda
# Processing Record 31 of Set 6 | buritis
# Processing Record 32 of Set 6 | nuuk
# Processing Record 33 of Set 6 | krasnoshchekovo
# Processing Record 34 of Set 6 | kapuskasing
# Processing Record 35 of Set 6 | sokur
# Processing Record 36 of Set 6 | worthington
# Processing Record 37 of Set 6 | castillos
# Processing Record 38 of Set 6 | ad dilam
# Processing Record 39 of Set 6 | kismayo
# Processing Record 40 of Set 6 | madimba
# Processing Record 41 of Set 6 | badger
# Processing Record 42 of Set 6 | puerto santa
# Processing Record 43 of Set 6 | puerto ayacucho
# Processing Record 44 of Set 6 | mao
# Processing Record 45 of Set 6 | ancud
# Processing Record 46 of Set 6 | machico
# Processing Record 47 of Set 6 | sunne
# Processing Record 48 of Set 6 | kongoussi
# Processing Record 49 of Set 6 | rongelap
# Processing Record 0 of Set 7 | velikiye luki
# Processing Record 1 of Set 7 | troitsko-pechorsk
# Processing Record 2 of Set 7 | nuku'alofa
# Processing Record 3 of Set 7 | laizhou
# Processing Record 4 of Set 7 | manokwari
# Processing Record 5 of Set 7 | lakhnadon
# Processing Record 6 of Set 7 | bureya
# Processing Record 7 of Set 7 | dera ghazi khan
# Processing Record 8 of Set 7 | fortuna
# Processing Record 9 of Set 7 | severo-yeniseyskiy
# Processing Record 10 of Set 7 | saint-joseph
# Processing Record 11 of Set 7 | tevragh zeina
# City not found. Skipping...
# Processing Record 12 of Set 7 | mount isa
# Processing Record 13 of Set 7 | salta
# Processing Record 14 of Set 7 | miri
# Processing Record 15 of Set 7 | motygino
# Processing Record 16 of Set 7 | ponta delgada
# Processing Record 17 of Set 7 | crane
# Processing Record 18 of Set 7 | tura
# Processing Record 19 of Set 7 | iskateley
# Processing Record 20 of Set 7 | corum
# Processing Record 21 of Set 7 | enewetak
# Processing Record 22 of Set 7 | cabedelo
# Processing Record 23 of Set 7 | geraldton
# Processing Record 24 of Set 7 | mawu
# Processing Record 25 of Set 7 | yallahs
# Processing Record 26 of Set 7 | caleta de carquin
# Processing Record 27 of Set 7 | torghay
# Processing Record 28 of Set 7 | cafayate
# Processing Record 29 of Set 7 | champasak
# Processing Record 30 of Set 7 | fortaleza
# Processing Record 31 of Set 7 | sinabang
# Processing Record 32 of Set 7 | new norfolk
# Processing Record 33 of Set 7 | yuanping
# Processing Record 34 of Set 7 | baikonur
# Processing Record 35 of Set 7 | duncan town
# City not found. Skipping...
# Processing Record 36 of Set 7 | manicore
# Processing Record 37 of Set 7 | sao felix do xingu
# Processing Record 38 of Set 7 | tarauaca
# Processing Record 39 of Set 7 | tezu
# Processing Record 40 of Set 7 | petropavlovsk-kamchatsky
# Processing Record 41 of Set 7 | bom jesus da lapa
# Processing Record 42 of Set 7 | simanggang
# Processing Record 43 of Set 7 | kiunga
# Processing Record 44 of Set 7 | burang
# Processing Record 45 of Set 7 | belokurikha
# Processing Record 46 of Set 7 | mamou
# Processing Record 47 of Set 7 | villa alberto andres alvarado aramburo
# City not found. Skipping...
# Processing Record 48 of Set 7 | waajid
# Processing Record 49 of Set 7 | amontada
# Processing Record 0 of Set 8 | zakynthos
# Processing Record 1 of Set 8 | cururupu
# Processing Record 2 of Set 8 | praia da vitoria
# Processing Record 3 of Set 8 | diego de almagro
# Processing Record 4 of Set 8 | tual
# Processing Record 5 of Set 8 | kenai
# Processing Record 6 of Set 8 | kilosa
# Processing Record 7 of Set 8 | karratha
# Processing Record 8 of Set 8 | alice springs
# Processing Record 9 of Set 8 | san pedro
# Processing Record 10 of Set 8 | riosucio
# Processing Record 11 of Set 8 | kalemie
# Processing Record 12 of Set 8 | imperatriz
# Processing Record 13 of Set 8 | newman
# Processing Record 14 of Set 8 | nadym
# Processing Record 15 of Set 8 | buka
# Processing Record 16 of Set 8 | minas de marcona
# Processing Record 17 of Set 8 | selfoss
# Processing Record 18 of Set 8 | port douglas
# Processing Record 19 of Set 8 | kishanganj
# Processing Record 20 of Set 8 | fort mcmurray
# Processing Record 21 of Set 8 | takamaka
# City not found. Skipping...
# Processing Record 22 of Set 8 | bam
# Processing Record 23 of Set 8 | bor
# Processing Record 24 of Set 8 | ceerigaabo
# Processing Record 25 of Set 8 | murashi
# Processing Record 26 of Set 8 | kisangani
# Processing Record 27 of Set 8 | heber springs
# Processing Record 28 of Set 8 | shumikha
# Processing Record 29 of Set 8 | santa cruz
# Processing Record 30 of Set 8 | itoman
# Processing Record 31 of Set 8 | afzalgarh
# Processing Record 32 of Set 8 | baker city
# Processing Record 33 of Set 8 | tweed heads
# Processing Record 34 of Set 8 | tazovsky
# Processing Record 35 of Set 8 | dolinsk
# Processing Record 36 of Set 8 | fuvahmulah
# City not found. Skipping...
# Processing Record 37 of Set 8 | hinton
# Processing Record 38 of Set 8 | jaru
# Processing Record 39 of Set 8 | besisahar
# Processing Record 40 of Set 8 | thunder bay
# Processing Record 41 of Set 8 | katsuren-haebaru
# Processing Record 42 of Set 8 | den burg
# Processing Record 43 of Set 8 | al jubayl
# Processing Record 44 of Set 8 | north bay
# Processing Record 45 of Set 8 | alappuzha
# Processing Record 46 of Set 8 | vangaindrano
# Processing Record 47 of Set 8 | brookings
# Processing Record 48 of Set 8 | acapulco de juarez
# Processing Record 49 of Set 8 | conde
# Processing Record 0 of Set 9 | chishtian
# Processing Record 1 of Set 9 | gosaba
# Processing Record 2 of Set 9 | villa independencia
# Processing Record 3 of Set 9 | lata
# Processing Record 4 of Set 9 | tympaki
# Processing Record 5 of Set 9 | rio grande
# Processing Record 6 of Set 9 | flying fish cove
# Processing Record 7 of Set 9 | saint-martin-des-champs
# Processing Record 8 of Set 9 | macau
# Processing Record 9 of Set 9 | prado
# Processing Record 10 of Set 9 | tsiombe
# Processing Record 11 of Set 9 | huesca
# Processing Record 12 of Set 9 | gadzhiyevo
# Processing Record 13 of Set 9 | mossel bay
# Processing Record 14 of Set 9 | mateur
# Processing Record 15 of Set 9 | inari
# Processing Record 16 of Set 9 | mejit
# Processing Record 17 of Set 9 | sanctuary point
# Processing Record 18 of Set 9 | kristiansund
# Processing Record 19 of Set 9 | hasaki
# Processing Record 20 of Set 9 | siverskiy
# Processing Record 21 of Set 9 | zeya
# Processing Record 22 of Set 9 | pachino
# Processing Record 23 of Set 9 | markova
# Processing Record 24 of Set 9 | whakatane
# Processing Record 25 of Set 9 | fale old settlement
# Processing Record 26 of Set 9 | cabo san lucas
# Processing Record 27 of Set 9 | guercif
# Processing Record 28 of Set 9 | queenstown
# Processing Record 29 of Set 9 | itumba
# Processing Record 30 of Set 9 | coal city
# Processing Record 31 of Set 9 | al ghayzah
# Processing Record 32 of Set 9 | kailua-kona
# Processing Record 33 of Set 9 | as sulayyil
# Processing Record 34 of Set 9 | port glaud
# City not found. Skipping...
# Processing Record 35 of Set 9 | san antonio oeste
# Processing Record 36 of Set 9 | cockburn town
# Processing Record 37 of Set 9 | hafnarfjordur
# Processing Record 38 of Set 9 | san andres
# Processing Record 39 of Set 9 | patacamaya
# Processing Record 40 of Set 9 | alappakkam
# Processing Record 41 of Set 9 | akim oda
# Processing Record 42 of Set 9 | lintong
# Processing Record 43 of Set 9 | morant bay
# Processing Record 44 of Set 9 | arta
# Processing Record 45 of Set 9 | arteche
# Processing Record 46 of Set 9 | roxas
# Processing Record 47 of Set 9 | mil'kovo
# Processing Record 48 of Set 9 | wonju
# Processing Record 49 of Set 9 | lyozna
# Processing Record 0 of Set 10 | nar'yan-mar
# Processing Record 1 of Set 10 | tazacorte
# Processing Record 2 of Set 10 | estancia
# Processing Record 3 of Set 10 | sinop
# Processing Record 4 of Set 10 | fort st. john
# Processing Record 5 of Set 10 | baruun-urt
# Processing Record 6 of Set 10 | tanrake village
# City not found. Skipping...
# Processing Record 7 of Set 10 | kataragama
# City not found. Skipping...
# Processing Record 8 of Set 10 | ouesso
# Processing Record 9 of Set 10 | san antonio de pale
# Processing Record 10 of Set 10 | puerto deseado
# Processing Record 11 of Set 10 | mugia
# Processing Record 12 of Set 10 | nova olimpia
# Processing Record 13 of Set 10 | figuig (centre)
# Processing Record 14 of Set 10 | margate
# Processing Record 15 of Set 10 | tinajo
# Processing Record 16 of Set 10 | ban mai
# Processing Record 17 of Set 10 | port alfred
# Processing Record 18 of Set 10 | lebu
# Processing Record 19 of Set 10 | tafuna
# Processing Record 20 of Set 10 | sonsorol village
# City not found. Skipping...
# Processing Record 21 of Set 10 | filingue
# Processing Record 22 of Set 10 | anabar
# City not found. Skipping...
# Processing Record 23 of Set 10 | gisborne
# Processing Record 24 of Set 10 | northam
# Processing Record 25 of Set 10 | vingt cinq
# City not found. Skipping...
# Processing Record 26 of Set 10 | lake havasu city
# Processing Record 27 of Set 10 | kayangel
# Processing Record 28 of Set 10 | barinas
# Processing Record 29 of Set 10 | vegreville
# Processing Record 30 of Set 10 | al jawf
# Processing Record 31 of Set 10 | guerrero negro
# Processing Record 32 of Set 10 | yima
# Processing Record 33 of Set 10 | chifeng
# Processing Record 34 of Set 10 | oliver
# Processing Record 35 of Set 10 | brooks
# Processing Record 36 of Set 10 | fada
# Processing Record 37 of Set 10 | yaren
# Processing Record 38 of Set 10 | alipur
# Processing Record 39 of Set 10 | port macquarie
# Processing Record 40 of Set 10 | shohimardon
# Processing Record 41 of Set 10 | ciudad bolivar
# Processing Record 42 of Set 10 | porto velho
# Processing Record 43 of Set 10 | phimai
# Processing Record 44 of Set 10 | barstow
# Processing Record 45 of Set 10 | maintirano
# Processing Record 46 of Set 10 | djidiouia
# Processing Record 47 of Set 10 | port shepstone
# Processing Record 48 of Set 10 | madhupur
# Processing Record 49 of Set 10 | fernley
# Processing Record 0 of Set 11 | esmeraldas
# Processing Record 1 of Set 11 | tyukhtet
# Processing Record 2 of Set 11 | mokhsogollokh
# Processing Record 3 of Set 11 | barentu
# Processing Record 4 of Set 11 | muisne
# Processing Record 5 of Set 11 | kashgar
# Processing Record 6 of Set 11 | labasa
# Processing Record 7 of Set 11 | pyt-yakh
# Processing Record 8 of Set 11 | padang
# Processing Record 9 of Set 11 | holbrook
# Processing Record 10 of Set 11 | rikaze
# Processing Record 11 of Set 11 | kovdor
# Processing Record 12 of Set 11 | olgii
# City not found. Skipping...
# Processing Record 13 of Set 11 | alibag
# Processing Record 14 of Set 11 | andergrove
# Processing Record 15 of Set 11 | wuchang
# Processing Record 16 of Set 11 | raton
# Processing Record 17 of Set 11 | bengkulu
# Processing Record 18 of Set 11 | kudahuvadhoo
# Processing Record 19 of Set 11 | jianguang
# Processing Record 20 of Set 11 | bulungu
# Processing Record 21 of Set 11 | solleftea
# Processing Record 22 of Set 11 | holualoa
# Processing Record 23 of Set 11 | hauterive
# Processing Record 24 of Set 11 | nova vicosa
# Processing Record 25 of Set 11 | achit
# Processing Record 26 of Set 11 | uyuni
# Processing Record 27 of Set 11 | suntar
# Processing Record 28 of Set 11 | al qadarif
# Processing Record 29 of Set 11 | coari
# Processing Record 30 of Set 11 | la sarre
# Processing Record 31 of Set 11 | navarre
# Processing Record 32 of Set 11 | serhetabat
# Processing Record 33 of Set 11 | saudarkrokur
# Processing Record 34 of Set 11 | antonio enes
# Processing Record 35 of Set 11 | umm kaddadah
# Processing Record 36 of Set 11 | camrose
# Processing Record 37 of Set 11 | butembo
# Processing Record 38 of Set 11 | indramayu
# Processing Record 39 of Set 11 | zhangjiakou shi xuanhua qu
# Processing Record 40 of Set 11 | preobrazheniye
# Processing Record 41 of Set 11 | jiuquan
# Processing Record 42 of Set 11 | zakamensk
# Processing Record 43 of Set 11 | la passe
# Processing Record 44 of Set 11 | gaspe
# Processing Record 45 of Set 11 | papao
# Processing Record 46 of Set 11 | glubokoye
# Processing Record 47 of Set 11 | khovd
# Processing Record 48 of Set 11 | abatskoye
# Processing Record 49 of Set 11 | port-vila
# Processing Record 0 of Set 12 | port isabel
# Processing Record 1 of Set 12 | urucara
# Processing Record 2 of Set 12 | koungou
# Processing Record 3 of Set 12 | la'ie
# Processing Record 4 of Set 12 | majene
# Processing Record 5 of Set 12 | bondo
# Processing Record 6 of Set 12 | berezovyy
# Processing Record 7 of Set 12 | calama
# Processing Record 8 of Set 12 | vernon
# Processing Record 9 of Set 12 | kargopol'
# Processing Record 10 of Set 12 | zouerate
# Processing Record 11 of Set 12 | aswan
# Processing Record 12 of Set 12 | serinhisar
# Processing Record 13 of Set 12 | el calafate
# Processing Record 14 of Set 12 | clarksville
# Processing Record 15 of Set 12 | oban
# Processing Record 16 of Set 12 | palu
# Processing Record 17 of Set 12 | hashtrud
# Processing Record 18 of Set 12 | bogorodsk
# Processing Record 19 of Set 12 | cuamba
# Processing Record 20 of Set 12 | portland
# Processing Record 21 of Set 12 | pointe-noire
# Processing Record 22 of Set 12 | pitea
# Processing Record 23 of Set 12 | roma
# Processing Record 24 of Set 12 | agaro
# Processing Record 25 of Set 12 | ezhva
# Processing Record 26 of Set 12 | reggane
# Processing Record 27 of Set 12 | chegdomyn
# Processing Record 28 of Set 12 | columbia
# Processing Record 29 of Set 12 | katabu
# Processing Record 30 of Set 12 | lensk
# Processing Record 31 of Set 12 | savanna-la-mar
# Processing Record 32 of Set 12 | wewak
# Processing Record 33 of Set 12 | basco
# Processing Record 34 of Set 12 | newark
# Processing Record 35 of Set 12 | qamdo
# Processing Record 36 of Set 12 | batangafo
# Processing Record 37 of Set 12 | dunedin
# Processing Record 38 of Set 12 | xianyang
# Processing Record 39 of Set 12 | yushu
# Processing Record 40 of Set 12 | inongo
# Processing Record 41 of Set 12 | hatillo
# Processing Record 42 of Set 12 | erriadh
# City not found. Skipping...
# Processing Record 43 of Set 12 | juneau
# Processing Record 44 of Set 12 | kharkhorin
# Processing Record 45 of Set 12 | arar
# Processing Record 46 of Set 12 | oranjestad
# Processing Record 47 of Set 12 | ta`u
# Processing Record 48 of Set 12 | campbell river
# Processing Record 49 of Set 12 | bikenibeu village
# Processing Record 0 of Set 13 | ordos
# City not found. Skipping...
# Processing Record 1 of Set 13 | sungai raya
# Processing Record 2 of Set 13 | ciudad del maiz
# Processing Record 3 of Set 13 | luderitz
# Processing Record 4 of Set 13 | puerto aysen
# Processing Record 5 of Set 13 | muskogee
# Processing Record 6 of Set 13 | ola
# Processing Record 7 of Set 13 | gurmatkal
# Processing Record 8 of Set 13 | santo antonio do ica
# Processing Record 9 of Set 13 | comodoro rivadavia
# Processing Record 10 of Set 13 | tacloban
# Processing Record 11 of Set 13 | daru
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          585
# Lat           585
# Lng           585
# Max Temp      585
# Humidity      585
# Cloudiness    585
# Wind Speed    585
# Country       585
# Date          585
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#          City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0   adamstown -25.0660 -130.1015     22.24        87           0        9.13
# 1    saldanha -33.0117   17.9442      6.03        85           0        4.74
# 2  champerico  14.3000  -91.9167     28.71        75          13        1.10
# 3      bethel  41.3712  -73.4140     24.55        87           0        1.54
# 4     pitimbu  -7.4706  -34.8086     23.33        82           2        6.41
#
#   Country        Date
# 0      PN  1722477969
# 1      ZA  1722477970
# 2      GT  1722477972
# 3      US  1722477973
# 4      BR  1722477921

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0         adamstown -25.0660 -130.1015     22.24        87           0
# 1          saldanha -33.0117   17.9442      6.03        85           0
# 2        champerico  14.3000  -91.9167     28.71        75          13
# 3            bethel  41.3712  -73.4140     24.55        87           0
# 4           pitimbu  -7.4706  -34.8086     23.33        82           2
#
#          Wind Speed Country        Date
# City_ID
# 0              9.13      PN  1722477969
# 1              4.74      ZA  1722477970
# 2              1.10      GT  1722477972
# 3              1.54      US  1722477973
# 4              6.41      BR  1722477921

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(city_data_df["Lat"], city_data_df["Max Temp"], edgecolors="black", linewidths=1, marker="o", alpha=0.8)
plt.title("Latitude vs. Max Temp (2024-07-31)")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (C)")
plt.grid(True)

# Incorporate the other graph properties
# YOUR CODE HERE
plt.xticks(np.arange(-60, 100, step=20))
plt.yticks(np.arange(0, max(city_data_df["Max Temp"])+10, step=10))
plt.tight_layout()

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(city_data_df["Lat"], city_data_df["Humidity"], edgecolors="black", linewidths=1, marker="o", alpha=0.8)
plt.title("Latitude vs. Humidity (2024-07-31)")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.grid(True)

# Incorporate the other graph properties
plt.xticks(np.arange(-60, 100, step=20))
plt.yticks(np.arange(0, max(city_data_df["Humidity"])+10, step=20))

plt.tight_layout()
# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
# YOUR CODE HERE
plt.scatter(city_data_df["Lat"], city_data_df["Cloudiness"], edgecolors="black", linewidths=1, marker="o", alpha=0.8)
plt.title("Latitude vs. Cloudiness (2024-07-31)")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid(True)

# Incorporate the other graph properties
# YOUR CODE HERE
plt.xticks(np.arange(-60, 100, step=20))
plt.yticks(np.arange(0, max(city_data_df["Cloudiness"])+10, step=20))
plt.tight_layout()

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
# YOUR CODE HERE
plt.scatter(city_data_df["Lat"], city_data_df["Wind Speed"], edgecolors="black", linewidths=1, marker="o", alpha=0.8)
plt.title("Latitude vs. Wind Speed (2024-07-31)")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (m/s)")
plt.grid(True)

# Incorporate the other graph properties
# YOUR CODE HERE
plt.xticks(np.arange(-60, 100, step=20))
plt.yticks(np.arange(0, 16, step=2))
plt.tight_layout()

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
# YOUR CODE HERE
def plot_linear_regression(x_values, y_values, title, text_coordinates, ylabel, plot_filename):
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    regress_values = x_values * slope + intercept
    line_eq = f"y = {round(slope,2)}x + {round(intercept,2)}"
    r_squared = rvalue**2
    print(f"The r^2 value is: {r_squared}")
    plt.scatter(x_values, y_values)
    plt.plot(x_values, regress_values, "r-")
    plt.annotate(line_eq, text_coordinates, fontsize=15, color="red")
    plt.title(title)
    plt.xlabel("Latitude")
    plt.ylabel(ylabel)
    # plt.grid(True)
    plt.savefig(plot_filename)
    plt.show()
    
    # print(f"The r^2 value is: {r_squared:.f}")

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
# YOUR CODE HERE
northern_hemi_df = city_data_df[city_data_df["Lat"] >= 0]
# Display sample data
northern_hemi_df.head()
# Out:
#                   City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 2           champerico  14.3000  -91.9167     28.71        75          13
# 3               bethel  41.3712  -73.4140     24.55        87           0
# 5         longyearbyen  78.2186   15.6401     10.91        87           0
# 7            brownwood  31.7093  -98.9912     32.00        47           0
# 8        pacific grove  36.6177 -121.9166     22.03        87          75
#
#          Wind Speed Country        Date
# City_ID
# 2              1.10      GT  1722477972
# 3              1.54      US  1722477973
# 5              0.00      SJ  1722477975
# 7              4.63      US  1722477977
# 8              3.09      US  1722477979

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
# YOUR CODE HERE
southern_hemi_df = city_data_df[city_data_df["Lat"] < 0]
# Display sample data
southern_hemi_df.head()
# Out:
#                                 City      Lat       Lng  Max Temp  Humidity  \
# City_ID
# 0                          adamstown -25.0660 -130.1015     22.24        87
# 1                           saldanha -33.0117   17.9442      6.03        85
# 4                            pitimbu  -7.4706  -34.8086     23.33        82
# 6        edinburgh of the seven seas -37.0676  -12.3116     11.84        61
# 9                       invercargill -46.4000  168.3500      6.68        76
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 0                 0        9.13      PN  1722477969
# 1                 0        4.74      ZA  1722477970
# 4                 2        6.41      BR  1722477921
# 6                40       10.55      SH  1722477976
# 9                 5        0.45      NZ  1722477980

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
# YOUR CODE HERE
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Max Temp"]
plot_linear_regression(x_values, y_values,"Latitude vs Max Temp (C)", (10, -20), "Max Temp (C)", "output_data/fig5.png")
# Out:
# The r^2 value is: 0.3749832624938424

# %%
# Linear regression on Southern Hemisphere
# YOUR CODE HERE
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Max Temp"]
plot_linear_regression(x_values, y_values, "Latitude vs Max Temp (C)", (-50, 30), "Max Temp (C)", "output_data/Fig6.png")
# Out:
# The r^2 value is: 0.6775552259311265

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Humidity"]
plot_linear_regression(x_values, y_values, "Latitude vs Humidity", (10, 40), "Humidity (%)", "output_data/Fig7.png")
# Out:
# The r^2 value is: 0.0007046960979657204

# %%
# Southern Hemisphere
# YOUR CODE HERE
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Humidity"]
plot_linear_regression(x_values, y_values, "Latitude vs Humidity", (-50, 40), "Humidity (%)", "output_data/Fig8.png")
# Out:
# The r^2 value is: 0.004297865565782947

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Cloudiness"]
plot_linear_regression(x_values, y_values, "Latitude vs Cloudiness", (10, 40), "Cloudiness (%)", "output_data/Fig9.png")
# Out:
# The r^2 value is: 0.0001269255737392763

# %%
# Southern Hemisphere
# YOUR CODE HERE
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Cloudiness"]
plot_linear_regression(x_values, y_values, "Latitude vs Cloudiness", (10, 40), "Cloudiness (%)", "output_data/Fig10.png")
# Out:
# The r^2 value is: 0.06756416178770917

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Wind Speed"]
plot_linear_regression(x_values, y_values, "Latitude vs Wind Speed", (10, 12), "Wind Speed (m/s)", "output_data/Fig11.png")
# Out:
# The r^2 value is: 0.005704155172713188

# %%
# Southern Hemisphere
# YOUR CODE HERE
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Wind Speed"]
plot_linear_regression(x_values, y_values, "Latitude vs Wind Speed", (10, 12), "Wind Speed (m/s)", "output_data/Fig12.png")
# Out:
# The r^2 value is: 0.015182962325743368

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE
